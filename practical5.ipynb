# %% [markdown]
# <a href="https://colab.research.google.com/github/anujsanap25-nxtwave/Data_science_lab_SE_72/blob/main/practical5.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import files

# %%
dataset = files.upload()
# Out:
#      <input type="file" id="files-9b817622-40b7-484d-b315-8446a79ede56" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-9b817622-40b7-484d-b315-8446a79ede56">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('loanapproval.csv')

# %%
df.head()
# Out:
#    applicant_id  age  gender marital_status  annual_income  loan_amount  \
# 0             1   59    Male       Divorced         100073         7169
# 1             2   49    Male        Married         112197        23556
# 2             3   35    Male       Divorced          84429        27052
# 3             4   63  Female         Single         124195        11313
# 4             5   28  Female        Married          81627        13315
#
#    credit_score  num_dependents  existing_loans_count employment_status  \
# 0           793               1                     1        Unemployed
# 1           789               0                     2          Employed
# 2           372               1                     4        Unemployed
# 3           808               3                     4     Self-employed
# 4           689               0                     1        Unemployed
#
#    loan_approved
# 0              1
# 1              1
# 2              0
# 3              1
# ...

# %%
df.columns[1]
# Out:
# 'gender'

# %%
df.tail()
# Out:
#      applicant_id  age  gender marital_status  annual_income  loan_amount  \
# 995           996   53  Female        Married         135598         6014
# 996           997   22    Male         Single         139028        15103
# 997           998   34  Female        Married         147517        21986
# 998           999   60  Female       Divorced          73161        49781
# 999          1000   60  Female         Single         141316        35471
#
#      credit_score  num_dependents  existing_loans_count employment_status  \
# 995           767               3                     2          Employed
# 996           662               0                     0     Self-employed
# 997           582               0                     2          Employed
# 998           635               4                     0        Unemployed
# 999           461               1                     1        Unemployed
#
#      loan_approved
# 995              1
# 996              1
# ...

# %%
print(len(df))
# Out:
# 1000

# %%
age_df = len(df[df['age'] > 50])
print(age_df)

multic_df = df[(df['gender'] == 'Male') & (df['loan_approved'] == 1)]
print(multic_df.head())
# Out:
# 320
#     age gender marital_status  annual_income  loan_amount  credit_score  \
# 0    59   Male       Divorced         100073         7169           793
# 1    49   Male        Married         112197        23556           789
# 6    59   Male       Divorced          57804        36778           668
# 13   60   Male        Married         114733        23800           719
# 14   44   Male        Married          89122        30372           551
#
#     num_dependents  existing_loans_count employment_status  loan_approved
# 0                1                     1        Unemployed              1
# 1                0                     2          Employed              1
# 6                1                     1          Employed              1
# 13               1                     4        Unemployed              1
# 14               0                     1          Employed              1

# %%
np.mean(df['age'])
# Out:
# np.float64(42.515)

# %%
np.max(df['annual_income'])
# Out:
# 149951

# %%
df = df.drop('applicant_id', axis=1)

# %%
print("DataFrame after dropping 'applicant_id' column:")
display(df.head())
# Out:
# DataFrame after dropping 'applicant_id' column:
#    age  gender marital_status  annual_income  loan_amount  credit_score  \
# 0   59    Male       Divorced         100073         7169           793
# 1   49    Male        Married         112197        23556           789
# 2   35    Male       Divorced          84429        27052           372
# 3   63  Female         Single         124195        11313           808
# 4   28  Female        Married          81627        13315           689
#
#    num_dependents  existing_loans_count employment_status  loan_approved
# 0               1                     1        Unemployed              1
# 1               0                     2          Employed              1
# 2               1                     4        Unemployed              0
# 3               3                     4     Self-employed              1
# 4               0                     1        Unemployed              1

# %%
df['credit_score'].describe()
# Out:
# count    1000.000000
# mean      576.125000
# std       155.921483
# min       300.000000
# 25%       443.750000
# 50%       573.500000
# 75%       713.250000
# max       849.000000
# Name: credit_score, dtype: float64

# %%
print("Operation to be performed ")
print("1.Print Features  ")
print("2.Print top 5 Records  ")
print("3.Print Bottom 5 Features  ")
print("4.Print stastical analysis For Anuual Income   ")
print("5.Print stastical analysis For loan amount   ")
print("6.Print stastical analysis For Credit Score  ")
print("7.Print stastical analysis For Age  ")
print("8.Print stastical analysis For Existing Loan  ")
print("9.Print number of client having age more than 50 ")
print("10.Print Client having geneder male and loan is approved ")
print("11. Print Unique values of the Gender Column ")
print("12. Print Value counts for the Marital Status Column")
print("13. Print Mean annual income grouped by gender")
# Out:
# Operation to be performed
# 1.Print Features
# 2.Print top 5 Records
# 3.Print Bottom 5 Features
# 4.Print stastical analysis For Anuual Income
# 5.Print stastical analysis For loan amount
# 6.Print stastical analysis For Credit Score
# 7.Print stastical analysis For Age
# 8.Print stastical analysis For Existing Loan
# 9.Print number of client having age more than 50
# 10.Print Client having geneder male and loan is approved
# 11. Print Unique values of the Gender Column
# 12. Print Value counts for the Marital Status Column
# 13. Print Mean annual income grouped by gender

# %%
c = int(input("Enter your choice "))
match c:
  case 1:
    print("Feature of the Columns are :")
    print(df.columns)
  case 2:
    print("top 5 Feature of the Record are :")
    print(df.head())
  case 3:
    print("Bottom 5 Feature of the Record are :")
    print(df.tail())
  case 4:
    print("stastical analysis For Anuual Income ")
    print(df['annual_income'].describe())
  case 5:
    print("stastical analysis For Loan Amount ")
    print(df['loan_amount'].describe())
  case 6:
    print("stastical analysis For Credit Score")
    print(df['credit_score'].describe())
  case 7:
    print("stastical analysis For Age")
    print(df['age'].describe())
  case 8:
    print("stastical analysis For Existing Loan ")
    print(df['existing_loans_count'].describe())
  case 9:
    print("number of client having age more than 50 ")
    print(len(df[df['age'] > 50]))
  case 10:
    print("Client having geneder male and loan is approved ")
    print(len(df[(df['gender'] == 'Male') & (df['loan_approved'] == 1)]))
  case 11:
    print("Unique values of the Gender Column ")
    print(df['gender'].unique())
  case 12:
    print("Value counts for the Marital Status Column")
    print(df['marital_status'].value_counts())
  case 13:
    print("Mean annual income grouped by gender")
    print(df.groupby('gender')['annual_income'].mean())
  case _:
    print("Invalid Choice")
# Out:
# Enter your choice 10
# Client having geneder male and loan is approved
# 386
