# %% [markdown]
# <a href="https://colab.research.google.com/github/anujsanap25-nxtwave/Data_science_lab_SE_72/blob/main/EvenOdd.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
num = int(input("Enter a number: "))

if (num % 2) == 0:
   print(f"{num} is an even number")
else:
   print(f"{num} is an odd number")
# Out:
# Enter a number: 6
# 6 is an even number
